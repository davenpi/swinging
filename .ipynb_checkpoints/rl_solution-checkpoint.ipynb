# %%
# %reset -f
import gym
import numpy as np
import scipy.integrate as si
import matplotlib.pyplot as plt
from stable_baselines3 import PPO, DDPG
from stable_baselines3.common.env_checker import check_env

# %%
class Swing(gym.Env):
    
    def __init__(
        self,
        L0: float = 1.0,
        phi_0: float = 10.0,
        omega_0: float = -.5,
        target_phi: float = np.pi / 2,
        dt: float = 0.01,
    ):
        super(Swing, self).__init__()
        self.g = 10
        self.L0 = L0
        self.Lmax = 2 * L0
        self.phi_0 = np.deg2rad(phi_0)
        self.omega_0 = omega_0
        self.phi = []
        self.phi.append(self.phi_0)
        self.omega = []
        self.omega.append(self.omega_0)
        self.dt = dt
        self.L = []
        self.L.append(self.L0)
        self.target_phi = target_phi
        self.pumps = 0
        self.action_space = gym.spaces.Box(low=0, high=1, shape=(1,))
        self.observation_space = gym.spaces.Box(low=-10, high=10, shape=(2,))

    def evolve(self):
        L_dot = (self.L[-1] - self.L[-2]) / self.dt
        omega_f = self.omega[-1] - self.dt * (
            2 * L_dot / self.L[-1] * self.omega[-1]
            + self.g / self.L[-1] * np.sin(self.phi[-1])
        )
        self.omega.append(omega_f)
        phi_new = self.phi[-1] + self.dt *omega_f
        self.phi.append(phi_new)
        self.pumps += 1

    def step(self, action):
        """
        Action is a choice of L
        """
        action = action.item()
        l_new = (action + 0.01) * self.Lmax
        # print(l_new)
        self.L.append(l_new)
        self.evolve()
        state = np.array([self.phi[-1], self.omega[-1]])

        if np.isclose(self.phi[-1], self.target_phi, rtol=0.1):
            reward = 10
            done = True
            state = self.reset()
        else:
            reward = -1
            done = False
            if self.pumps > 15:
                done = True
                state = self.reset()
        
        return state, reward, done, {}

    def reset(self):
        self.clear()
        self.phi.append(self.phi_0)
        self.omega.append(self.omega_0)
        self.L.append(self.L0)
        state = np.array([self.phi[-1], self.omega[-1]])
        self.pumps = 0
        return state

    def render():
        pass

    def clear(self):
        self.L.clear()
        self.omega.clear()
        self.phi.clear()

# %%
env = Swing()

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=int(2e5))
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.1     |
# |    ep_rew_mean     | -14.1    |
# | time/              |          |
# |    fps             | 2247     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.3         |
# |    ep_rew_mean          | -14.7        |
# | time/                   |              |
# |    fps                  | 1596         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0015143543 |
# |    clip_fraction        | 0.00327      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.117       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.5         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000451    |
# |    std                  | 0.991        |
# |    value_loss           | 44           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.4         |
# |    ep_rew_mean          | -14.7        |
# | time/                   |              |
# |    fps                  | 1454         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0030279788 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00194     |
# |    std                  | 0.988        |
# |    value_loss           | 38.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.7         |
# |    ep_rew_mean          | -15.3        |
# | time/                   |              |
# |    fps                  | 1364         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0026388844 |
# |    clip_fraction        | 0.00654      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0011      |
# |    std                  | 0.985        |
# |    value_loss           | 33.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15          |
# |    ep_rew_mean          | -13.8       |
# | time/                   |             |
# |    fps                  | 1332        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004190886 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00336    |
# |    std                  | 0.983       |
# |    value_loss           | 25.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.7         |
# |    ep_rew_mean          | -13.5        |
# | time/                   |              |
# |    fps                  | 1319         |
# |    iterations           | 6            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0021831691 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.092        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.85         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00026     |
# |    std                  | 0.983        |
# |    value_loss           | 24.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 15.2          |
# |    ep_rew_mean          | -14.3         |
# | time/                   |               |
# |    fps                  | 1304          |
# |    iterations           | 7             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00050988235 |
# |    clip_fraction        | 0.00171       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.113         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.75          |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000792     |
# |    std                  | 0.985         |
# |    value_loss           | 19.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.4         |
# |    ep_rew_mean          | -14.6        |
# | time/                   |              |
# |    fps                  | 1302         |
# |    iterations           | 8            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0012330381 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.85         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000244    |
# |    std                  | 0.988        |
# |    value_loss           | 15.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.1         |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 1297         |
# |    iterations           | 9            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0032448093 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.263        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.987        |
# |    value_loss           | 17.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.4         |
# |    ep_rew_mean          | -14.6        |
# | time/                   |              |
# |    fps                  | 1303         |
# |    iterations           | 10           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0033340636 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.48         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.986        |
# |    value_loss           | 15.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.2         |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 1305         |
# |    iterations           | 11           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0022431936 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.29         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.983        |
# |    value_loss           | 12.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.4         |
# |    ep_rew_mean          | -14.8        |
# | time/                   |              |
# |    fps                  | 1297         |
# |    iterations           | 12           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0039833942 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.303        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.84         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 6.41e-05     |
# |    std                  | 0.976        |
# |    value_loss           | 15.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.2        |
# |    ep_rew_mean          | -14.3       |
# | time/                   |             |
# |    fps                  | 1294        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.003285276 |
# |    clip_fraction        | 0.00293     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.22        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00101    |
# |    std                  | 0.967       |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.3        |
# |    ep_rew_mean          | -14.6       |
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 14          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.003022938 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.01        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00343    |
# |    std                  | 0.961       |
# |    value_loss           | 14.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.6         |
# |    ep_rew_mean          | -15.2        |
# | time/                   |              |
# |    fps                  | 1291         |
# |    iterations           | 15           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0034648874 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.27         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.956        |
# |    value_loss           | 13.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | -15.2       |
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 16          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.001650447 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.45        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00275    |
# |    std                  | 0.94        |
# |    value_loss           | 10.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.3         |
# |    ep_rew_mean          | -14.4        |
# | time/                   |              |
# |    fps                  | 1283         |
# |    iterations           | 17           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0022791638 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.467        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.03         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 0.945        |
# |    value_loss           | 10.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.2         |
# |    ep_rew_mean          | -14.2        |
# | time/                   |              |
# |    fps                  | 1277         |
# |    iterations           | 18           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0024616541 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.74         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000725    |
# |    std                  | 0.949        |
# |    value_loss           | 13.4         |
# ------------------------------------------
