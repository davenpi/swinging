# %%
import copy
import gym
import numpy as np
import scipy.integrate as si
import matplotlib.pyplot as plt
import matplotlib.ticker as tck
from stable_baselines3 import PPO, DDPG
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy

# %%
class Swing(gym.Env):
    def __init__(self):
        super(Swing, self).__init__()
        self.lmin = 2
        self.lmax = 2.5
        self.phidot_0 = -0.1
        self.target = np.pi
        self.time = 0
        self.pumps = 0
        self.tau = np.sqrt(self.lmin / 9.81) / 4
        self.ldot_max = (self.lmax - self.lmin) / self.tau
        self.observation_space = gym.spaces.Box(
            low=np.array([0, -10, self.lmin]),
            high=np.array([2 * np.pi, 10, self.lmax]),  # phi, phi dot, L
        )
        self.observation_space = gym.spaces.Box(
            low=np.array([-1, self.lmin]), high=np.array([10, self.lmax])
        )
        self.action_space = gym.spaces.Box(low=-np.array([1]), high=np.array([1]))
        self.phi = [np.pi / 8]
        self.phi_dot = [self.phidot_0]
        self.L = [self.lmin]
        self.Ldot_hist = []

    def fun(self, t, y, ldot, g=9.81):
        """Define system of equations to simulate"""
        y0_dot = y[1]
        y1_dot = -(2 * ldot / y[2]) * y[1] - (g / y[2]) * np.sin(y[0])
        y2_dot = ldot
        y_dot = np.hstack((y0_dot, y1_dot, y2_dot))
        return y_dot

    def forward(self, ldot):
        """Simulate the swing forward"""
        sol = si.solve_ivp(
            self.fun,
            [self.time, self.time + self.tau],
            y0=[self.phi[-1], self.phi_dot[-1], self.L[-1]],
            args=[ldot],
        )
        phi = np.mod(sol.y[0], 2 * np.pi)
        self.phi.extend(list(phi[1:]))
        phi_dot = sol.y[1]
        self.phi_dot.extend(list(phi_dot[1:]))
        L = sol.y[2]
        self.L.extend(list(L[1:]))
        self.time += self.tau
        self.pumps += 1
        pass

    def check_valid_action(self, ldot):
        """Check if an action will take us out of bounds. if so don't allow it."""
        next_l = self.L[-1] + self.tau * ldot
        if next_l > self.lmax:
            ldot = (self.lmax - self.L[-1]) / self.tau
        elif next_l < self.lmin:
            ldot = (self.lmin - self.L[-1]) / self.tau
        else:
            ldot = ldot
        return ldot

    def step(self, action):
        """Take action and simulate"""
        ldot = self.ldot_max * action[0]
        ldot = self.check_valid_action(ldot)
        self.Ldot_hist.append(ldot)
        self.forward(ldot)
        # state = np.array([self.phi[-1], self.phi_dot[-1], self.L[-1]], dtype=np.float32)
        state = np.array([self.phi_dot[-1], self.L[-1]], dtype=np.float32)
        if np.isclose(state[0], self.target, rtol=0.05):
            reward = 10
            done = True
        elif self.pumps > 10_000:
            reward = -1
            done = True
        else:
            reward = -1
            done = False
        info = {}
        return state, reward, done, info

    def reset(self):
        """Reset system to beginning of episode."""
        self.time = 0
        self.pumps = 0
        self.L = [self.lmin]
        self.phi = [np.pi / 8]
        self.phi_dot = [self.phidot_0]
        self.Ldot_hist.clear()
        # state = np.array([self.phi[-1], self.phi_dot[-1], self.L[-1]], dtype=np.float32)
        state = np.array([self.phi_dot[-1], self.L[-1]], dtype=np.float32)
        return state

    def render(self):
        pass

# %%
env = Swing()
# Out:
# /Users/iandavenport/opt/anaconda3/lib/python3.7/site-packages/gym/spaces/box.py:74: UserWarning: WARN: Box bound precision lowered by casting to float32
#   "Box bound precision lowered by casting to {}".format(self.dtype)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=3.5e5)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | -459     |
# | time/              |          |
# |    fps             | 1027     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 585          |
# |    ep_rew_mean          | -574         |
# | time/                   |              |
# |    fps                  | 912          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054652635 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.00102      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.6         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00341     |
# |    std                  | 0.984        |
# |    value_loss           | 118          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 823         |
# |    ep_rew_mean          | -812        |
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004153664 |
# |    clip_fraction        | 0.00386     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.00812     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -9.22e-05   |
# |    std                  | 0.979       |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 892         |
# |    ep_rew_mean          | -881        |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.001853778 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.000628    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000555   |
# |    std                  | 0.996       |
# |    value_loss           | 110         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 831          |
# |    ep_rew_mean          | -820         |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0019917348 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00109      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00223     |
# |    std                  | 0.997        |
# |    value_loss           | 93.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 950          |
# |    ep_rew_mean          | -939         |
# | time/                   |              |
# |    fps                  | 838          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0045967097 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.000734     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00251     |
# |    std                  | 0.99         |
# |    value_loss           | 75.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 922         |
# |    ep_rew_mean          | -911        |
# | time/                   |             |
# |    fps                  | 831         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006669869 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 2.81e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.12        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00161    |
# |    std                  | 0.974       |
# |    value_loss           | 62.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 897          |
# |    ep_rew_mean          | -886         |
# | time/                   |              |
# |    fps                  | 827          |
# |    iterations           | 8            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0018911168 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000114     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 0.963        |
# |    value_loss           | 84.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 929          |
# |    ep_rew_mean          | -918         |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 9            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0033892097 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 5.44e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.8         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 0.964        |
# |    value_loss           | 72.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 929         |
# |    ep_rew_mean          | -918        |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 10          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008825505 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 1.47e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40          |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000777   |
# |    std                  | 0.951       |
# |    value_loss           | 38.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 929          |
# |    ep_rew_mean          | -918         |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 11           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0028217908 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -7.53e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.221        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 0.956        |
# |    value_loss           | 13.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.19e+03   |
# |    ep_rew_mean          | -1.18e+03  |
# | time/                   |            |
# |    fps                  | 814        |
# |    iterations           | 12         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01128399 |
# |    clip_fraction        | 0.0248     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.000803   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0189     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.000484  |
# |    std                  | 0.945      |
# |    value_loss           | 7.65       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.22e+03     |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 13           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0028539917 |
# |    clip_fraction        | 0.00269      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 1.01e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.272        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000113    |
# |    std                  | 0.937        |
# |    value_loss           | 35.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.19e+03     |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 14           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0010331243 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 5.3e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.3         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000205    |
# |    std                  | 0.938        |
# |    value_loss           | 36.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -1.16e+03   |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 15          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.002741673 |
# |    clip_fraction        | 0.00601     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.000316    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000949   |
# |    std                  | 0.926       |
# |    value_loss           | 101         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 16           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0013950759 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0172       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00031     |
# |    std                  | 0.925        |
# |    value_loss           | 73.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | -1.18e+03   |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 17          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002038186 |
# |    clip_fraction        | 0.00112     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.0365      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000661   |
# |    std                  | 0.923       |
# |    value_loss           | 74          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.19e+03     |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 18           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0015869883 |
# |    clip_fraction        | 0.00679      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0564       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.7         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000231    |
# |    std                  | 0.924        |
# |    value_loss           | 40.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 19           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0021009604 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -4.95        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0483       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00189     |
# |    std                  | 0.949        |
# |    value_loss           | 0.666        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.12e+03      |
# |    ep_rew_mean          | -1.11e+03     |
# | time/                   |               |
# |    fps                  | 809           |
# |    iterations           | 20            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00072289613 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.00171       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 242           |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -7.1e-05      |
# |    std                  | 0.943         |
# |    value_loss           | 161           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.12e+03      |
# |    ep_rew_mean          | -1.11e+03     |
# | time/                   |               |
# |    fps                  | 809           |
# |    iterations           | 21            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00039880094 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.0212        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 16.9          |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 4.68e-06      |
# |    std                  | 0.941         |
# |    value_loss           | 118           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | -1.1e+03    |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 22          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008138495 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0164      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.1        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00322    |
# |    std                  | 0.94        |
# |    value_loss           | 81.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | -1.1e+03    |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 23          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003231768 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0264      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00231    |
# |    std                  | 0.93        |
# |    value_loss           | 82.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 24          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008722785 |
# |    clip_fraction        | 0.0376      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0192      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.5        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00147    |
# |    std                  | 0.927       |
# |    value_loss           | 81.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 25           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0051577445 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.0225      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.914        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00157     |
# |    std                  | 0.922        |
# |    value_loss           | 65.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | -1.08e+03   |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 26          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.003352391 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0226      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.258       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000956   |
# |    std                  | 0.912       |
# |    value_loss           | 42.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 27          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008720122 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.00983    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00195    |
# |    std                  | 0.906       |
# |    value_loss           | 128         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.1e+03      |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 28           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0011683609 |
# |    clip_fraction        | 0.00161      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0237       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.5         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000864    |
# |    std                  | 0.919        |
# |    value_loss           | 85           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.1e+03      |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 29           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0011449241 |
# |    clip_fraction        | 0.00376      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0194       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.000324     |
# |    std                  | 0.913        |
# |    value_loss           | 84.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | -1.07e+03   |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 30          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.001225186 |
# |    clip_fraction        | 0.00107     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.6        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000235   |
# |    std                  | 0.903       |
# |    value_loss           | 73.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.07e+03     |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 31           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0020145187 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.0541       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.01         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00176     |
# |    std                  | 0.896        |
# |    value_loss           | 86.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06e+03     |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 32           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0035971627 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0263       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.59         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00327     |
# |    std                  | 0.885        |
# |    value_loss           | 125          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | -1.06e+03   |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 33          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003174196 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.0237      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.847       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000846   |
# |    std                  | 0.882       |
# |    value_loss           | 42.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -1.02e+03   |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 34          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004259835 |
# |    clip_fraction        | 0.0139      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.0699      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.71        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -8.69e-05   |
# |    std                  | 0.887       |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | -981        |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 35          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.001233048 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.043       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.8        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000658   |
# |    std                  | 0.879       |
# |    value_loss           | 159         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 987          |
# |    ep_rew_mean          | -976         |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 36           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0042142775 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 93.4         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00242     |
# |    std                  | 0.877        |
# |    value_loss           | 186          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 979         |
# |    ep_rew_mean          | -968        |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 37          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.003007106 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.00738     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.000572   |
# |    std                  | 0.878       |
# |    value_loss           | 81.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | -980        |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 38          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007871555 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.7        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00201    |
# |    std                  | 0.878       |
# |    value_loss           | 69.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 969         |
# |    ep_rew_mean          | -958        |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 39          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007986311 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.0269      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00387    |
# |    std                  | 0.858       |
# |    value_loss           | 81.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 956          |
# |    ep_rew_mean          | -945         |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 40           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0027112844 |
# |    clip_fraction        | 0.00303      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.0338       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.1         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000356    |
# |    std                  | 0.857        |
# |    value_loss           | 159          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 932          |
# |    ep_rew_mean          | -921         |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 41           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0011672803 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.0498       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.9         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00101     |
# |    std                  | 0.857        |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 919         |
# |    ep_rew_mean          | -908        |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 42          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.001044199 |
# |    clip_fraction        | 0.00166     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0719      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000575   |
# |    std                  | 0.858       |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 894         |
# |    ep_rew_mean          | -883        |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 43          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005565628 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.0164     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.78        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00299    |
# |    std                  | 0.85        |
# |    value_loss           | 119         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 887          |
# |    ep_rew_mean          | -876         |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 44           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0045250617 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.4         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00199     |
# |    std                  | 0.835        |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 896          |
# |    ep_rew_mean          | -885         |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 45           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0034635512 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.6         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 0.817        |
# |    value_loss           | 109          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 896         |
# |    ep_rew_mean          | -885        |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 46          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004097083 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0913      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.1        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00222    |
# |    std                  | 0.813       |
# |    value_loss           | 117         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 903          |
# |    ep_rew_mean          | -892         |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 47           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0049684346 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -3.47        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00866      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00493     |
# |    std                  | 0.839        |
# |    value_loss           | 0.635        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 855           |
# |    ep_rew_mean          | -844          |
# | time/                   |               |
# |    fps                  | 811           |
# |    iterations           | 48            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00021744636 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.24         |
# |    explained_variance   | 0.0381        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 16.6          |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000184     |
# |    std                  | 0.837         |
# |    value_loss           | 119           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 844          |
# |    ep_rew_mean          | -833         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 49           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0011814516 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0233       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 102          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000589    |
# |    std                  | 0.836        |
# |    value_loss           | 193          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 739          |
# |    ep_rew_mean          | -728         |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 50           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0017910514 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0846       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.9         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00107     |
# |    std                  | 0.836        |
# |    value_loss           | 172          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 725          |
# |    ep_rew_mean          | -714         |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 51           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0017458205 |
# |    clip_fraction        | 0.00186      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 189          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00138     |
# |    std                  | 0.841        |
# |    value_loss           | 209          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 681         |
# |    ep_rew_mean          | -670        |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 52          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.000691301 |
# |    clip_fraction        | 0.000293    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.0565      |
# |    learning_rate        | 0.0003      |
# ...
# |    ep_len_mean          | 585          |
# |    ep_rew_mean          | -574         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 58           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0038742286 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0584       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.6         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00249     |
# |    std                  | 0.838        |
# |    value_loss           | 140          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 569           |
# |    ep_rew_mean          | -558          |
# | time/                   |               |
# |    fps                  | 810           |
# |    iterations           | 59            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 120832        |
# | train/                  |               |
# |    approx_kl            | 0.00057721615 |
# |    clip_fraction        | 0.00708       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.24         |
# |    explained_variance   | 0.0606        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 16.6          |
# |    n_updates            | 580           |
# |    policy_gradient_loss | 0.000165      |
# |    std                  | 0.838         |
# |    value_loss           | 107           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 554          |
# |    ep_rew_mean          | -543         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 60           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0032511945 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0658       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.6         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.831        |
# |    value_loss           | 204          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 557          |
# |    ep_rew_mean          | -546         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 61           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0016399783 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.6         |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.0012      |
# |    std                  | 0.826        |
# |    value_loss           | 96.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 557          |
# |    ep_rew_mean          | -546         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 62           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0008341557 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.00948      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.3         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -8.75e-05    |
# |    std                  | 0.826        |
# |    value_loss           | 112          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 549          |
# |    ep_rew_mean          | -538         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 63           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0020785232 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0581       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.000636    |
# |    std                  | 0.835        |
# |    value_loss           | 176          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 541          |
# |    ep_rew_mean          | -530         |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 64           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0068397513 |
# |    clip_fraction        | 0.0842       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.35         |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.834        |
# |    value_loss           | 95.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 531         |
# |    ep_rew_mean          | -520        |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 65          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.003859301 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.00221    |
# |    std                  | 0.83        |
# |    value_loss           | 108         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 524          |
# |    ep_rew_mean          | -513         |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 66           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 135168       |
# | train/                  |              |
# |    approx_kl            | 0.0010486548 |
# |    clip_fraction        | 0.00752      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.000522    |
# |    std                  | 0.83         |
# |    value_loss           | 173          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 528          |
# |    ep_rew_mean          | -517         |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 67           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 137216       |
# | train/                  |              |
# |    approx_kl            | 0.0038019093 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0502       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 660          |
# |    policy_gradient_loss | 0.000372     |
# |    std                  | 0.829        |
# |    value_loss           | 211          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 521          |
# |    ep_rew_mean          | -510         |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 68           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0089354925 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.021        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.7         |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00225     |
# |    std                  | 0.816        |
# |    value_loss           | 76.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 505         |
# |    ep_rew_mean          | -494        |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 69          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.003397185 |
# |    clip_fraction        | 0.0124      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0876      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.00142    |
# |    std                  | 0.818       |
# |    value_loss           | 224         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 501          |
# |    ep_rew_mean          | -490         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 70           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0045629027 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.191        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 133          |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.000262    |
# |    std                  | 0.822        |
# |    value_loss           | 157          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 485          |
# |    ep_rew_mean          | -474         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 71           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 145408       |
# | train/                  |              |
# |    approx_kl            | 0.0010015133 |
# |    clip_fraction        | 0.00835      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.2         |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.000488    |
# |    std                  | 0.823        |
# |    value_loss           | 63.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 489          |
# |    ep_rew_mean          | -478         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 72           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0019547897 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.6         |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.00288     |
# |    std                  | 0.819        |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 502          |
# |    ep_rew_mean          | -492         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 73           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0003040906 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.0804       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18           |
# |    n_updates            | 720          |
# |    policy_gradient_loss | 0.000648     |
# |    std                  | 0.821        |
# |    value_loss           | 106          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -489         |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 74           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0057265814 |
# |    clip_fraction        | 0.00986      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.000393    |
# |    std                  | 0.811        |
# |    value_loss           | 103          |
# ------------------------------------------

# %%
model.save("ldot_controller")
