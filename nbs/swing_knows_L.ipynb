# %%
import copy
import gym
import numpy as np
import scipy.integrate as si
import matplotlib.pyplot as plt
import matplotlib.ticker as tck
from stable_baselines3 import PPO, DDPG
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy

# %%
class Swing(gym.Env):
    def __init__(self, target=np.pi / 2, L0=0.8, omega_0=-0.0):
        super(Swing, self).__init__()
        self.observation_space = gym.spaces.Box(
            low=np.array([0, -10, 0]), high=np.array([2 * np.pi, 10, 1])
        )

        self.action_space = gym.spaces.Box(
            low=np.array([-1, -1]), high=np.array([1, 1])
        )
        self.L0 = L0
        self.omega_0 = omega_0
        self.target = target
        self.time = 0
        self.dt = 0.1
        self.pumps = 0
        self.phi0 = np.pi / 8
        self.phi = [self.phi0]
        self.phi_dot = [self.omega_0]
        self.L = [self.L0]
        self.a_history = []
        self.d_history = []
        self.full_phi_hist = [self.phi0]
        self.full_phi_dot_hist = [self.omega_0]

    def fun(self, t, y, a, d, L0=1, tau=1, g=9.81):
        y0_dot = y[1]
        y1_dot = (
            -(2 * y[1] / y[2]) * ((y[2] - L0) / tau + y[2] * a * np.cos(y[0] + d) / tau)
            - g * np.sin(y[0]) / y[2]
        )
        y2_dot = -(y[2] - L0) / tau + y[2] * a * np.cos(y[0] + d) / tau
        y_dot = np.hstack((y0_dot, y1_dot, y2_dot))
        return y_dot

    def step(self, action):
        a = action[0]
        self.a_history.append(a)
        d = np.pi * action[1]
        self.d_history.append(d)
        sol = si.solve_ivp(
            self.fun,
            [self.time, self.time + 1],
            y0=[self.phi[-1], self.phi_dot[-1], self.L[-1]],
            args=(a, d),
        )
        self.full_phi_hist.append(sol.y[0][1:])
        self.full_phi_dot_hist.append(sol.y[1][1:])
        phi = np.mod(sol.y[0][-1], 2 * np.pi)
        self.phi.append(phi)
        phi_dot = sol.y[1][-1]
        self.phi_dot.append(phi_dot)
        L = sol.y[2][-1]
        self.L.append(L)
        state = np.array([phi, phi_dot, L])
        if np.isclose(state[0], self.target, rtol=0.1):
            reward = 10
            done = True
            # print("Success! :-)")
        elif self.pumps > 50:
            reward = -1
            done = True
        else:
            reward = -1
            done = False
        info = {}
        self.time += self.dt
        self.pumps += 1
        return state, reward, done, info

    def reset(self):
        self.time = 0
        self.pumps = 0
        self.L = [self.L0]
        self.phi = [self.phi0]
        self.phi_dot = [self.omega_0]
        state = np.array([self.phi[-1], self.phi_dot[-1], self.L[-1]])
        self.a_history.clear()
        self.d_history.clear()
        self.full_phi_dot_hist.clear()
        self.full_phi_dot_hist.append(self.omega_0)
        self.full_phi_hist.clear()
        self.full_phi_hist.append(self.phi0)
        return state

    def render(self):
        pass

# %%
env = Swing(target=np.pi)
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1e5)
# Out:
# /Users/iandavenport/Desktop/research/chameleon/venv/lib/python3.7/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.5     |
# |    ep_rew_mean     | -24.9    |
# | time/              |          |
# |    fps             | 663      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.3         |
# |    ep_rew_mean          | -24.4        |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0062071974 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.0281      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00394     |
# |    std                  | 0.997        |
# |    value_loss           | 65           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32           |
# |    ep_rew_mean          | -24.9        |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 3            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0062721903 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00592     |
# |    std                  | 1            |
# |    value_loss           | 70.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.1         |
# |    ep_rew_mean          | -22.6        |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 4            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0061144563 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.306        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00648     |
# |    std                  | 1.01         |
# |    value_loss           | 80.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.5        |
# |    ep_rew_mean          | -15.4       |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 5           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006474605 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00708    |
# |    std                  | 1.02        |
# |    value_loss           | 94.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.6         |
# |    ep_rew_mean          | -17.1        |
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 6            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0064567495 |
# |    clip_fraction        | 0.0812       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52           |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0081      |
# |    std                  | 1.02         |
# |    value_loss           | 93.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.2        |
# |    ep_rew_mean          | -8.24       |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 7           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008126682 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00792    |
# |    std                  | 1.02        |
# |    value_loss           | 83.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.4        |
# |    ep_rew_mean          | -6.2        |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 8           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007914612 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.7        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 1.02        |
# |    value_loss           | 92.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.7        |
# |    ep_rew_mean          | -7.12       |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 9           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005658122 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.0542      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00502    |
# |    std                  | 1.03        |
# |    value_loss           | 78.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.3        |
# |    ep_rew_mean          | -6.82       |
# | time/                   |             |
# |    fps                  | 499         |
# |    iterations           | 10          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009573268 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.174       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00894    |
# |    std                  | 1.02        |
# |    value_loss           | 65          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | -5.4        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 11          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006340065 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.0811      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00543    |
# |    std                  | 1.03        |
# |    value_loss           | 68          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.4         |
# |    ep_rew_mean          | -3.62        |
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 12           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0065483097 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.3         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00787     |
# |    std                  | 1.03         |
# |    value_loss           | 60.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | -2.82       |
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 13          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006758137 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00502    |
# |    std                  | 1.04        |
# |    value_loss           | 55.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.3         |
# |    ep_rew_mean          | -3.45        |
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 14           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0067936424 |
# |    clip_fraction        | 0.0821       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34           |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 1.04         |
# |    value_loss           | 57.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.9         |
# |    ep_rew_mean          | -1.15        |
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 15           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0072419136 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23           |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00773     |
# |    std                  | 1.05         |
# |    value_loss           | 54.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 16           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0067303954 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.0113       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.2         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00454     |
# |    std                  | 1.05         |
# |    value_loss           | 48.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.1         |
# |    ep_rew_mean          | -1.21        |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 17           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0052327886 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0206       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 1.05         |
# |    value_loss           | 42           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.7         |
# |    ep_rew_mean          | -0.76        |
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 18           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0044478243 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.0347       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00333     |
# |    std                  | 1.07         |
# |    value_loss           | 43.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.3        |
# |    ep_rew_mean          | -3.29       |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 19          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005518368 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.0447      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00502    |
# |    std                  | 1.08        |
# |    value_loss           | 43          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.4         |
# |    ep_rew_mean          | -0.53        |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 20           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0048389975 |
# |    clip_fraction        | 0.0537       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.0592       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.1         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 1.09         |
# |    value_loss           | 40.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.6         |
# |    ep_rew_mean          | 0.37         |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 21           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0061901845 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.0452       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00422     |
# |    std                  | 1.09         |
# |    value_loss           | 38.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 0.17        |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 22          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004664245 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.0176      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00416    |
# |    std                  | 1.09        |
# |    value_loss           | 41          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.2         |
# |    ep_rew_mean          | -0.19        |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 23           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0069153807 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.00597     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.9         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00339     |
# |    std                  | 1.08         |
# |    value_loss           | 43.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.92         |
# |    ep_rew_mean          | 1.08         |
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 24           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0078120385 |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.0156       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22           |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00687     |
# |    std                  | 1.06         |
# |    value_loss           | 42.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.7         |
# |    ep_rew_mean          | 0.29         |
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 25           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0053636227 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0224       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.6         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00395     |
# |    std                  | 1.05         |
# |    value_loss           | 34.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.66         |
# |    ep_rew_mean          | 1.34         |
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 26           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0029844549 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.0212       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.3         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000675    |
# |    std                  | 1.05         |
# |    value_loss           | 35.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.45        |
# |    ep_rew_mean          | 1.55        |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 27          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008907389 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.075       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00689    |
# |    std                  | 1.04        |
# |    value_loss           | 27.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.7         |
# |    ep_rew_mean          | -0.7         |
# | time/                   |              |
# |    fps                  | 497          |
# |    iterations           | 28           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0073051555 |
# |    clip_fraction        | 0.0733       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.000472     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.2         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00642     |
# |    std                  | 1.03         |
# |    value_loss           | 31.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.2        |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 29          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006332107 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.00857     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 1.02        |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | 0.92        |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 30          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005457448 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | -0.0184     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00472    |
# |    std                  | 1.02        |
# |    value_loss           | 34.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 0.87        |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 31          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.006266702 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.000566    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00246    |
# |    std                  | 1           |
# |    value_loss           | 42.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.67        |
# |    ep_rew_mean          | 2.22        |
# | time/                   |             |
# |    fps                  | 496         |
# |    iterations           | 32          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006933688 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.0125      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00485    |
# |    std                  | 0.988       |
# |    value_loss           | 39.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.6         |
# |    ep_rew_mean          | 0.3          |
# | time/                   |              |
# |    fps                  | 494          |
# |    iterations           | 33           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0038079224 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.0186       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 0.99         |
# |    value_loss           | 34.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.5         |
# |    ep_rew_mean          | 0.52         |
# | time/                   |              |
# |    fps                  | 494          |
# |    iterations           | 34           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0054022335 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 0.0144       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.99         |
# |    value_loss           | 40.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.97        |
# |    ep_rew_mean          | 3.03        |
# | time/                   |             |
# |    fps                  | 494         |
# |    iterations           | 35          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007777118 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.0159      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00312    |
# |    std                  | 0.976       |
# |    value_loss           | 40.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.68         |
# |    ep_rew_mean          | 2.32         |
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 36           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0066386876 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | -0.0586      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.4         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00476     |
# |    std                  | 0.959        |
# |    value_loss           | 35.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11           |
# |    ep_rew_mean          | -0.15        |
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 37           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0065218634 |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.0232       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20           |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00551     |
# |    std                  | 0.95         |
# |    value_loss           | 38.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.17        |
# |    ep_rew_mean          | 1.83        |
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 38          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.005096564 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | -0.0084     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00547    |
# |    std                  | 0.937       |
# |    value_loss           | 35.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 0.07        |
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 39          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009117581 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | -0.0418     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00851    |
# |    std                  | 0.93        |
# |    value_loss           | 33.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64         |
# |    ep_rew_mean          | 2.36         |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 40           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0072978474 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | -0.001       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00247     |
# |    std                  | 0.933        |
# |    value_loss           | 40.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.86         |
# |    ep_rew_mean          | 2.14         |
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 41           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0072872257 |
# |    clip_fraction        | 0.0734       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.0022       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.3         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00368     |
# |    std                  | 0.925        |
# |    value_loss           | 36.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.85         |
# |    ep_rew_mean          | 2.15         |
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 42           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0070474762 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.00206      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.9         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00385     |
# |    std                  | 0.91         |
# |    value_loss           | 38.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.81        |
# |    ep_rew_mean          | 3.08        |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 43          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008732205 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.00164     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00648    |
# |    std                  | 0.896       |
# |    value_loss           | 36.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.11         |
# |    ep_rew_mean          | 2.89         |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 44           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0077658235 |
# |    clip_fraction        | 0.0796       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.00383      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.4         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00616     |
# |    std                  | 0.895        |
# |    value_loss           | 36.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.97         |
# |    ep_rew_mean          | 2.92         |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 45           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0069780666 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | -0.000147    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.1         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00246     |
# |    std                  | 0.887        |
# |    value_loss           | 32.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.56        |
# |    ep_rew_mean          | 2.44        |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 46          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007545227 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.025       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00357    |
# |    std                  | 0.873       |
# |    value_loss           | 37.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.04         |
# |    ep_rew_mean          | 3.85         |
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 47           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0075291493 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.0031       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00392     |
# |    std                  | 0.863        |
# |    value_loss           | 38.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.73        |
# |    ep_rew_mean          | 4.27        |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 48          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005577964 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.0679      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00417    |
# |    std                  | 0.847       |
# |    value_loss           | 39          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.16         |
# |    ep_rew_mean          | 3.84         |
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 49           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0053784633 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.0288       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00237     |
# |    std                  | 0.845        |
# |    value_loss           | 32.6         |
# ------------------------------------------

# %%
# model.save("fullswingup_knowingL")

# %%
model = PPO.load("fullswingup_knowingL.zip", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
obs = env.reset()
done = False
i = 0
while not done:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    i += 1

a_actions = copy.deepcopy(env.a_history)
a_actions.insert(0, 0)

d_actions = copy.deepcopy(env.d_history)
d_actions.insert(0, 0)

# %%
times = np.linspace(1, len(env.phi), len(env.phi))
plt.figure(figsize=(8, 8))
plt.plot(times, env.phi, "-o")
plt.title(r"$\phi$ at each step")
plt.xlabel("time", fontsize=15)
plt.ylabel(r"$\phi$", fontsize=15)
plt.yticks(
    np.linspace(0, 2 * np.pi, 5),
    labels=["0", r"$\frac{\pi}{2}$", r"$\pi$", r"$\frac{3\pi}{2}$", r"2$\pi$"],
    fontsize=15,
)
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(times, env.L, "-o")
plt.xlabel("time", fontsize=15)
plt.ylabel(r"L", fontsize=15)
plt.title(r"$L(t)$", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(times, a_actions, "-o")
plt.xlabel("time", fontsize=15)
plt.ylabel("a", fontsize=15)
plt.title(r"$a(t)$", fontsize=15)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 10))

ax.plot(times, d_actions, "-o")
# ax.yaxis.set_major_formatter(tck.FormatStrFormatter('$\pi$'))
# ax.yaxis.set_major_locator(tck.MultipleLocator(base=0.5))
# plt.plot(times, d_actions[-23:], "-o")
ax.set_xlabel("time", fontsize=15)
ax.set_ylabel(r"$\delta$", fontsize=15)
ax.set_title(r"$\delta(t)$", fontsize=15)
ax.set_yticks(
    np.linspace(-np.pi, np.pi, 3), labels=[r"-$\pi$", r"0", r"$\pi$"], fontsize=15
)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(env.phi, env.L, "-o")
ax.set_xlabel(r"$\phi$", fontsize=15)
ax.set_ylabel(r"$L$", fontsize=15)
ax.set_title(r"$L$ vs $\phi$", fontsize=15)
ax.set_xticks(
    np.linspace(0, 2 * np.pi, 5),
    labels=["0", r"$\frac{\pi}{2}$", r"$\pi$", r"$\frac{3\pi}{2}$", r"2$\pi$"],
    fontsize=15,
)
plt.show()
